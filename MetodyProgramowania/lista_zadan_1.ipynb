# %%
2 * 3 + 4
# Out:
# - : int = 10

# %%
2 * (3 * 4)
# Out:
# - : int = 24

# %%
let a = 3
# Out:
# val a : int = 3

# %%
let b = a + 1
# Out:
# val b : int = 4

# %%
if b > a && b < a * b then b else a
# Out:
# - : int = 4

# %%
2 + (if b > a then b else a);
# Out:
# - : int = 6

# %%
let a = if b * b > b then b else -1 in a * b
# Out:
# - : int = 16

# %%
"foo" ^ 42
# Out:
# File "[9]", line 1, characters 8-10:
# 1 | "foo" ^ 42
#             ^^
# Error: This expression has type int but an expression was expected of type
#          string

# %%
"foo" ^ string_of_int 42
# Out:
# - : string = "foo42"

# %%
1. = 2
# Out:
# File "[13]", line 1, characters 5-6:
# 1 | 1. = 2
#          ^
# Error: This expression has type int but an expression was expected of type
#          float
#   Hint: Did you mean `2.'?

# %%
fun a -> a + 5
# Out:
# - : int -> int = <fun>

# %%
fun a -> if a > 5 then a else "foo"
# Out:
# File "[15]", line 1, characters 30-35:
# 1 | fun a -> if a > 5 then a else "foo"
#                                   ^^^^^
# Error: This expression has type string but an expression was expected of type
#          int

# %%
fun a b -> if a > 5 then a else b
# Out:
# - : int -> int -> int = <fun>

# %%
fun a b ->
    let c = a = b in
    if a > 3 && b = "foo"
    then c
    else false
# Out:
# File "[18]", line 3, characters 20-25:
# 3 |     if a > 3 && b = "foo"
#                         ^^^^^
# Error: This expression has type string but an expression was expected of type
#          int

# %%
fun a -> let f a b = a * a + b * b in f (f a a) a
# Out:
# - : int -> int = <fun>

# %%
let f a = a > 2 in if 3 > 2 then true else f (f 2)
# Out:
# File "[2]", line 1, characters 45-50:
# 1 | let f a = a > 2 in if 3 > 2 then true else f (f 2)
#                                                  ^^^^^
# Error: This expression has type bool but an expression was expected of type
#          int

# %%
x;;
# Out:
# File "[1]", line 1, characters 0-1:
# 1 | x;;
#     ^
# Error: Unbound value x

# %%
let x = 3 in x + y
# Out:
# File "[2]", line 1, characters 17-18:
# 1 | let x = 3 in x + y
#                      ^
# Error: Unbound value y

# %%
let x = 1
and y = x + 2
in x + y
# Out:
# File "[1]", line 2, characters 8-9:
# 2 | and y = x + 2
#             ^
# Error: Unbound value x

# %%
let x = 1 in
let y = x + 2 in
x + y
# Out:
# - : int = 4

# %% [markdown]
# ##### let f x y = x * y * z

# %%
let f x = 
    let g y z = x * y * z in
g (h x) z;;
# Out:
# File "[6]", line 3, characters 3-4:
# 3 | g (h x) z;;
#        ^
# Error: Unbound value h

# %%
let sum_of_squares_of_two_max_elements x y z = 
    let sq a = a * a in
    sq x + sq y + sq z - sq (min (min x y) z)
# Out:
# val sum_of_squares_of_two_max_elements : int -> int -> int -> int = <fun>

# %%
sum_of_squares_of_two_max_elements 2 1 3
# Out:
# - : int = 13

# %%
let a_plus_abs_b a b =
    (if b > 0 then (+) else (-)) a b
# Out:
# val a_plus_abs_b : int -> int -> int = <fun>

# %%
a_plus_abs_b 1 (-5)
# Out:
# - : int = 6

# %%
let rec f() = f()
# Out:
# val f : unit -> 'a = <fun>

# %%
let test x y =
    if x = 0 then 0 else y
# Out:
# val test : int -> int -> int = <fun>

# %%
test 0 (f())
# Out:
# Exception: Sys.Break.

# %%
Jeśli interpreter używa gorliwej kolejności obliczania to wpadnie w nieskończoną rekurencję
podczas obliczania wartości argumentu y.

Gdy interpreter używa leniwej kolejności obliczania to stwierdzi że argument x jest równy 0 i 
bez obliczania y zwróci 0.
