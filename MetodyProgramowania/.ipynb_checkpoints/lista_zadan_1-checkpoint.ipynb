# %%
2 * 3 + 4
# Out:
# - : int = 10

# %%
2 * (3 * 4)
# Out:
# - : int = 24

# %%
let a = 3
# Out:
# val a : int = 3

# %%
let b = a + 1
# Out:
# val b : int = 4

# %%
if b > a && b < a * b then b else a
# Out:
# - : int = 4

# %%
2 + (if b > a then b else a);
# Out:
# - : int = 6

# %%
let a = if b * b > b then b else -1 in a * b
# Out:
# - : int = 16
