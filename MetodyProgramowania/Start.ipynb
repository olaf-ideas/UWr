# %%
let square x = x * x
# Out:
# val square : int -> int = <fun>

# %%
2 + square 2
# Out:
# - : int = 6

# %%
let increment x = x + 1
# Out:
# val increment : int -> int = <fun>

# %%
2 + square (increment 1)
# Out:
# - : int = 6
